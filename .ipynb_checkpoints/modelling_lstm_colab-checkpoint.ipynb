# %% [markdown]
# <a href="https://colab.research.google.com/github/andre-la-machado/cnr/blob/master/modelling_lstm_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LSTM Modelling

# %% [markdown]
# On this Notebook, a LSTM Model will be tried for the Competitition Data.

# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
sns.set_style('darkgrid')
from cnr_methods import get_selected_features, transform_data, revert_data, get_simplified_data
import random

from sklearn.model_selection import TimeSeriesSplit, train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
import tensorflow as tf
print(tf.test.is_built_with_cuda())  # Sanity check: GPU available to tf or not
print(tf.test.is_built_with_gpu_support())
print(tf.config.list_physical_devices('GPU'))
print(tf.__version__)  # Check if __version__>="2.0.0"
print(tf.keras.__version__)
# Out:
# True
# True
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2.3.0
# 2.4.0

# %% [markdown]
# ## Read Data

# %% [markdown]
# Here, the data used correspond to the results of the Feature Engineering and Selection Step. For simplicity, during Hyperparameter Optimization, only Wind Farm 3 Training Data is used.

# %%
full_data = pd.read_csv(r"C:\Users\andre_\OneDrive\Documentos\Feature Selection\Selected_Features_Data.csv")

#full_data = full_data.rename({'Unnamed: 0' : 'Time'},axis=1)
full_data = full_data.set_index('Time')

full_label = pd.read_csv(r'C:\Users\andre_\OneDrive\Documentos\GitHub\cnr\Data\Y_train.csv')

# %%
full_data = full_data[['ID', 'WF', 'U_100m', 'V_100m', 'U_10m', 'V_10m', 'T', 'CLCT', 'Set',
       'Wind Speed 100m', 'Wind Direction 100m', 'Wind Speed 10m',
       'Wind Direction 10m','Month_Number']]

# %%
X = full_data[full_data['Set']=='Train']

WF = 'WF3'
X = X[X['WF']==WF]
y = full_label[full_label['ID'].isin(X['ID'])]

# %%
X.head()
# Out:
#                         ID   WF    U_100m    V_100m     U_10m     V_10m  \
# Time
# 2018-05-01 01:00:00  12479  WF3  5.789500  3.820200  1.054669  1.317597
# 2018-05-01 02:00:00  12480  WF3  6.003300  3.920600  0.876879  1.483483
# 2018-05-01 03:00:00  12481  WF3  5.931829  0.907656  0.949640  1.419591
# 2018-05-01 04:00:00  12482  WF3  5.205300  1.683800  1.027462  1.029786
# 2018-05-01 05:00:00  12483  WF3  4.845900  0.702200  1.011645  0.785352
#
#                            T       CLCT    Set  Wind Speed 100m  \
# Time
# 2018-05-01 01:00:00  275.690  86.504507  Train         6.936299
# 2018-05-01 02:00:00  275.770  98.976088  Train         7.170127
# 2018-05-01 03:00:00  276.875  64.193607  Train         6.000870
# 2018-05-01 04:00:00  275.650  57.482484  Train         5.470862
# 2018-05-01 05:00:00  275.530  89.971463  Train         4.896512
#
#                      Wind Direction 100m  Wind Speed 10m  Wind Direction 10m  \
# Time
# 2018-05-01 01:00:00             0.583268        1.687717            0.895782
# 2018-05-01 02:00:00             0.578533        1.723264            1.036951
# 2018-05-01 03:00:00             0.151837        1.707938            0.981212
# 2018-05-01 04:00:00             0.312855        1.454695            0.786528
# 2018-05-01 05:00:00             0.143904        1.280704            0.660129
#
#                      Month_Number
# Time
# 2018-05-01 01:00:00             5
# 2018-05-01 02:00:00             5
# 2018-05-01 03:00:00             5
# 2018-05-01 04:00:00             5
# 2018-05-01 05:00:00             5

# %% [markdown]
# ## Scaling Data

# %% [markdown]
# For a better performance of the Network, here functions are created to scale data between [-1,1] using MinMaxScaler. For the Direction Data, presented in degrees, Sin and Cos are calculated, which naturally have values in this same scale.

# %%
def preprocessing_X(X):

  scaler = MinMaxScaler(feature_range=(-1,1))

  X_saved_columns = X[['ID','WF','Set','Month_Number']]
  X_saved_columns = X_saved_columns.reset_index().drop('Time',axis=1)
  X = X.drop(['ID','WF','Set','Month_Number'],axis=1)

  # Fill NaN's
  #X = X.fillna(method="ffill", axis=1) # ZOH
  #X = X.fillna(0)

  # Scaling Data
  directions = X[['Wind Direction 100m', 'Wind Direction 10m']]
  directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
  directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
  directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
  directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
  directions = directions.drop(['Wind Direction 100m', 'Wind Direction 10m'],axis=1)
  directions = directions.reset_index().drop('Time',axis=1)

  X = X.drop(['Wind Direction 100m', 'Wind Direction 10m'],axis=1)
  X_columns = X.columns

  X = scaler.fit_transform(X)
  X = pd.DataFrame(X,columns=X_columns)
  X = pd.concat([X,directions],axis=1)
  X = pd.concat([X,X_saved_columns],axis=1)

  X = X.fillna(-2)

  return X

# %%
def preprocessing_y(y):

  scaler = MinMaxScaler(feature_range=(-1,1))

  #y = y.fillna(method="ffill", axis=1) # ZOH
  #y = y.fillna(0)
  y = y.drop('ID',axis=1)
  y = scaler.fit_transform(y)
  y = pd.DataFrame(y)
  y = y.fillna(-2)

  return y,scaler

# %%
y.shape
# Out:
# (6239, 2)

# %% [markdown]
# ## Subsets Creation

# %% [markdown]
# Here, the Data is converted to a group of subsets where each subset has n_steps of past data.

# %%
n_steps = 60

# %%
# split a multivariate sequence into samples
def split_sequences(X, y = None, n_steps = 1):
	sample_X, sample_y = list(), list()
	for i in range(len(X)):
		# find the end of this pattern
		end_ix = i + n_steps
		# check if we are beyond the dataset
		if end_ix > len(X):
			break
		# gather input and output parts of the pattern
		seq_x = X[i:end_ix, :]
		sample_X.append(seq_x)
		if y is not None:
			seq_y = y[end_ix-1,-1]
			sample_y.append(seq_y)
	return np.array(sample_X), np.array(sample_y)

# %%
def shift_save(df,n_steps):
  empty = pd.DataFrame(np.zeros((n_steps-1,df.shape[1])),columns=df.columns)
  df = pd.concat([empty,df])
  return df

# %%
sample_X,sample_y = split_sequences(X.values,y.values,n_steps)

# %%
n_features = sample_X.shape[2] - 2

# %% [markdown]
# ## Model

# %% [markdown]
# Here, a function to create the Model usin Keras is defined.

# %%
def LSTM_Model(input_shape, batch_size=1):
  # Numerical branch

  input_layer = tf.keras.Input(shape = input_shape,batch_size = batch_size)

  hidden_1 = tf.keras.layers.LSTM(units=128,return_sequences=True,stateful=True)(input_layer)
  hidden_1 = tf.keras.layers.Dropout(0.4)(hidden_1)

  hidden_2 = tf.keras.layers.LSTM(units=87,return_sequences=True,stateful=True)(hidden_1)
  hidden_2 = tf.keras.layers.Dropout(0.4)(hidden_2)

  hidden_3 = tf.keras.layers.LSTM(units=57,stateful=True)(hidden_2)
  hidden_3 = tf.keras.layers.Dropout(0.4)(hidden_3)

  # Output
  #outputs = tf.keras.layers.PReLU()(hidden_2)
  #outputs = tf.keras.layers.Dropout(rate=0.2)(hidden_2)
  outputs = tf.keras.layers.Dense(units=1)(hidden_3)

  model = tf.keras.Model(inputs=input_layer, outputs=outputs)

  return model

# %%
input_shape = (n_steps,n_features)

# %%
model = LSTM_Model(input_shape)

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(1, 60, 12)]             0
# _________________________________________________________________
# lstm (LSTM)                  (1, 60, 128)              72192
# _________________________________________________________________
# dropout (Dropout)            (1, 60, 128)              0
# _________________________________________________________________
# lstm_1 (LSTM)                (1, 60, 87)               75168
# _________________________________________________________________
# dropout_1 (Dropout)          (1, 60, 87)               0
# _________________________________________________________________
# lstm_2 (LSTM)                (1, 57)                   33060
# _________________________________________________________________
# dropout_2 (Dropout)          (1, 57)                   0
# _________________________________________________________________
# dense (Dense)                (1, 1)                    58
# =================================================================
# Total params: 180,478
# Trainable params: 180,478
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Validation

# %% [markdown]
# Here, a Validation Process is done using the SKlearn's TimeSeriesSplit with 5 folds. The results of RMSE for each Split on Train, Validation and Test sets are plotted in the end.

# %%
random.seed(317)
tf.random.set_seed(317)

patience = 3
epochs = 10
k_fold_splits = 5
total_it = 50
monitor = "root_mean_squared_error"
batch_size = 1

# %%
# Define Time Split Cross Validation
tscv = TimeSeriesSplit(n_splits=k_fold_splits)

# Separating Data from Hold Out Set

X_cv, _, y_cv, _ = train_test_split(X, y, test_size=0.125, shuffle=False)

train_scores = np.empty(0)
val_scores = np.empty(0)
test_scores = np.empty(0)
for train_index, test_index in tscv.split(X_cv):

    #train_index = train_index[-n_rows:]
    #test_index = test_index[-n_rows:]

    # Get the Data of the Split
    X_train, X_test = X_cv.iloc[train_index], X_cv.iloc[test_index]
    y_train, y_test = y_cv.iloc[train_index], y_cv.iloc[test_index]

    # Separating Training Set of Split on Train and Validation Subsets
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.143, shuffle=False)

    # Preprocessing Data
    X_train = preprocessing_X(X_train)
    X_val = preprocessing_X(X_val)
    X_test = preprocessing_X(X_test)

    X_train = X_train.drop(['ID','WF','Set','Month_Number'],axis=1)
    X_val = X_val.drop(['ID','WF','Set','Month_Number'],axis=1)
    X_test = X_test.drop(['ID','WF','Set','Month_Number'],axis=1)

    y_train,_ = preprocessing_y(y_train)
    y_val,_ = preprocessing_y(y_val)
    y_test,_ = preprocessing_y(y_test)

    # Reshape Data
    X_train, y_train = split_sequences(X_train.values,y_train.values,n_steps)
    X_val, y_val = split_sequences(X_val.values,y_val.values,n_steps)
    X_test, y_test = split_sequences(X_test.values,y_test.values,n_steps)

    # Create Model
    model = LSTM_Model(input_shape,batch_size=batch_size)

    # Callbacks
    callbacks_list = [tf.keras.callbacks.EarlyStopping(monitor=monitor, patience=patience, verbose=0, min_delta=1e-8)]

    # Train the Model
    model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])
    history = model.fit(x = X_train, y = y_train, batch_size = batch_size, epochs = epochs, validation_data = (X_val, y_val), callbacks=callbacks_list,shuffle=False)

    # Train and Validation Score
    train_score = np.array(history.history['root_mean_squared_error']).mean()
    val_score = np.array(history.history['val_root_mean_squared_error']).mean()

    # Test Score
    preds = model.predict(X_test,batch_size = batch_size,callbacks=callbacks_list)
    preds = tf.cast(preds, tf.float32)
    y_test = tf.cast(y_test, tf.float32)

    m = tf.keras.metrics.RootMeanSquaredError()
    m.update_state(y_test,preds)
    test_score = m.result().numpy()

    train_scores = np.append(train_scores,train_score)
    val_scores = np.append(val_scores,val_score)
    test_scores = np.append(test_scores,test_score)
# Out:
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 724/724 [==============================] - 9s 12ms/step - loss: 0.1401 - root_mean_squared_error: 0.3743 - val_loss: 0.1790 - val_root_mean_squared_error: 0.4231
# Epoch 2/10
# 724/724 [==============================] - 7s 10ms/step - loss: 0.1416 - root_mean_squared_error: 0.3763 - val_loss: 0.2016 - val_root_mean_squared_error: 0.4490
# Epoch 3/10
# 724/724 [==============================] - 7s 10ms/step - loss: 0.1383 - root_mean_squared_error: 0.3719 - val_loss: 0.1496 - val_root_mean_squared_error: 0.3868
# Epoch 4/10
# 724/724 [==============================] - 7s 10ms/step - loss: 0.1261 - root_mean_squared_error: 0.3551 - val_loss: 0.1073 - val_root_mean_squared_error: 0.3276
# Epoch 5/10
# 724/724 [==============================] - 7s 10ms/step - loss: 0.1118 - root_mean_squared_error: 0.3344 - val_loss: 0.0657 - val_root_mean_squared_error: 0.2564
# Epoch 6/10
# 724/724 [==============================] - 7s 10ms/step - loss: 0.0973 - root_mean_squared_error: 0.3119 - val_loss: 0.0544 - val_root_mean_squared_error: 0.2331
# Epoch 7/10
# 724/724 [==============================] - 7s 10ms/step - loss: 0.0922 - root_mean_squared_error: 0.3037 - val_loss: 0.0709 - val_root_mean_squared_error: 0.2662
# Epoch 8/10
# 724/724 [==============================] - 7s 10ms/step - loss: 0.0914 - root_mean_squared_error: 0.3024 - val_loss: 0.0546 - val_root_mean_squared_error: 0.2336
# Epoch 9/10
# 724/724 [==============================] - 7s 10ms/step - loss: 0.1215 - root_mean_squared_error: 0.3486 - val_loss: 0.1220 - val_root_mean_squared_error: 0.3493
# Epoch 10/10
# 724/724 [==============================] - 7s 10ms/step - loss: 0.0879 - root_mean_squared_error: 0.2966 - val_loss: 0.0487 - val_root_mean_squared_error: 0.2208
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 1503/1503 [==============================] - 17s 11ms/step - loss: 0.1048 - root_mean_squared_error: 0.3238 - val_loss: 0.2458 - val_root_mean_squared_error: 0.4958
# Epoch 2/10
# 1503/1503 [==============================] - 15s 10ms/step - loss: 0.1012 - root_mean_squared_error: 0.3181 - val_loss: 0.2166 - val_root_mean_squared_error: 0.4654
# Epoch 3/10
# 1503/1503 [==============================] - 15s 10ms/step - loss: 0.0953 - root_mean_squared_error: 0.3087 - val_loss: 0.0786 - val_root_mean_squared_error: 0.2804
# Epoch 4/10
# 1503/1503 [==============================] - 15s 10ms/step - loss: 0.0702 - root_mean_squared_error: 0.2650 - val_loss: 0.0583 - val_root_mean_squared_error: 0.2414
# Epoch 5/10
# 1503/1503 [==============================] - 15s 10ms/step - loss: 0.0578 - root_mean_squared_error: 0.2405 - val_loss: 0.0448 - val_root_mean_squared_error: 0.2117
# Epoch 6/10
# 1503/1503 [==============================] - 15s 10ms/step - loss: 0.0550 - root_mean_squared_error: 0.2346 - val_loss: 0.0528 - val_root_mean_squared_error: 0.2299
# Epoch 7/10
# 1503/1503 [==============================] - 15s 10ms/step - loss: 0.0519 - root_mean_squared_error: 0.2278 - val_loss: 0.0762 - val_root_mean_squared_error: 0.2761
# Epoch 8/10
# 1503/1503 [==============================] - 15s 10ms/step - loss: 0.0497 - root_mean_squared_error: 0.2229 - val_loss: 0.1261 - val_root_mean_squared_error: 0.3550
# Epoch 9/10
# 1503/1503 [==============================] - 15s 10ms/step - loss: 0.0480 - root_mean_squared_error: 0.2192 - val_loss: 0.1031 - val_root_mean_squared_error: 0.3211
# Epoch 10/10
# 1503/1503 [==============================] - 15s 10ms/step - loss: 0.0456 - root_mean_squared_error: 0.2134 - val_loss: 0.1212 - val_root_mean_squared_error: 0.3482
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 2282/2282 [==============================] - 25s 11ms/step - loss: 0.1106 - root_mean_squared_error: 0.3325 - val_loss: 0.1367 - val_root_mean_squared_error: 0.3697
# Epoch 2/10
# 2282/2282 [==============================] - 23s 10ms/step - loss: 0.1018 - root_mean_squared_error: 0.3191 - val_loss: 0.1337 - val_root_mean_squared_error: 0.3657
# Epoch 3/10
# 2282/2282 [==============================] - 23s 10ms/step - loss: 0.1047 - root_mean_squared_error: 0.3235 - val_loss: 0.1195 - val_root_mean_squared_error: 0.3457
# Epoch 4/10
# 2282/2282 [==============================] - 23s 10ms/step - loss: 0.0819 - root_mean_squared_error: 0.2862 - val_loss: 0.0999 - val_root_mean_squared_error: 0.3160
# Epoch 5/10
# 2282/2282 [==============================] - 22s 10ms/step - loss: 0.0641 - root_mean_squared_error: 0.2531 - val_loss: 0.0770 - val_root_mean_squared_error: 0.2776
# Epoch 6/10
# 2282/2282 [==============================] - 22s 10ms/step - loss: 0.0517 - root_mean_squared_error: 0.2273 - val_loss: 0.1755 - val_root_mean_squared_error: 0.4189
# Epoch 7/10
# 2282/2282 [==============================] - 23s 10ms/step - loss: 0.0459 - root_mean_squared_error: 0.2142 - val_loss: 0.1330 - val_root_mean_squared_error: 0.3647
# Epoch 8/10
# 2282/2282 [==============================] - 23s 10ms/step - loss: 0.0446 - root_mean_squared_error: 0.2112 - val_loss: 0.1548 - val_root_mean_squared_error: 0.3935
# Epoch 9/10
# 2282/2282 [==============================] - 23s 10ms/step - loss: 0.0457 - root_mean_squared_error: 0.2137 - val_loss: 0.1598 - val_root_mean_squared_error: 0.3998
# Epoch 10/10
# 2282/2282 [==============================] - 23s 10ms/step - loss: 0.0429 - root_mean_squared_error: 0.2071 - val_loss: 0.1190 - val_root_mean_squared_error: 0.3450
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 3061/3061 [==============================] - 32s 10ms/step - loss: 0.0971 - root_mean_squared_error: 0.3115 - val_loss: 0.1883 - val_root_mean_squared_error: 0.4340
# Epoch 2/10
# 3061/3061 [==============================] - 31s 10ms/step - loss: 0.0980 - root_mean_squared_error: 0.3131 - val_loss: 0.1915 - val_root_mean_squared_error: 0.4376
# Epoch 3/10
# 3061/3061 [==============================] - 30s 10ms/step - loss: 0.0998 - root_mean_squared_error: 0.3159 - val_loss: 0.1462 - val_root_mean_squared_error: 0.3823
# Epoch 4/10
# 3061/3061 [==============================] - 30s 10ms/step - loss: 0.0613 - root_mean_squared_error: 0.2475 - val_loss: 0.1111 - val_root_mean_squared_error: 0.3333
# Epoch 5/10
# 3061/3061 [==============================] - 30s 10ms/step - loss: 0.0450 - root_mean_squared_error: 0.2122 - val_loss: 0.0594 - val_root_mean_squared_error: 0.2437
# Epoch 6/10
# 3061/3061 [==============================] - 30s 10ms/step - loss: 0.0406 - root_mean_squared_error: 0.2014 - val_loss: 0.0522 - val_root_mean_squared_error: 0.2286
# Epoch 7/10
# 3061/3061 [==============================] - 30s 10ms/step - loss: 0.0420 - root_mean_squared_error: 0.2050 - val_loss: 0.0530 - val_root_mean_squared_error: 0.2303
# Epoch 8/10
# 3061/3061 [==============================] - 30s 10ms/step - loss: 0.0382 - root_mean_squared_error: 0.1954 - val_loss: 0.0528 - val_root_mean_squared_error: 0.2298
# Epoch 9/10
# 3061/3061 [==============================] - 30s 10ms/step - loss: 0.0350 - root_mean_squared_error: 0.1870 - val_loss: 0.0601 - val_root_mean_squared_error: 0.2452
# Epoch 10/10
# 3061/3061 [==============================] - 30s 10ms/step - loss: 0.0359 - root_mean_squared_error: 0.1895 - val_loss: 0.0572 - val_root_mean_squared_error: 0.2391
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 3840/3840 [==============================] - 40s 10ms/step - loss: 0.0744 - root_mean_squared_error: 0.2727 - val_loss: 0.1532 - val_root_mean_squared_error: 0.3914
# Epoch 2/10
# 3840/3840 [==============================] - 38s 10ms/step - loss: 0.0731 - root_mean_squared_error: 0.2703 - val_loss: 0.1482 - val_root_mean_squared_error: 0.3850
# Epoch 3/10
# 3840/3840 [==============================] - 38s 10ms/step - loss: 0.0473 - root_mean_squared_error: 0.2175 - val_loss: 0.1116 - val_root_mean_squared_error: 0.3341
# Epoch 4/10
# 3840/3840 [==============================] - 38s 10ms/step - loss: 0.0346 - root_mean_squared_error: 0.1860 - val_loss: 0.0939 - val_root_mean_squared_error: 0.3064
# Epoch 5/10
# 3840/3840 [==============================] - 38s 10ms/step - loss: 0.0297 - root_mean_squared_error: 0.1724 - val_loss: 0.0802 - val_root_mean_squared_error: 0.2833
# Epoch 6/10
# 3840/3840 [==============================] - 38s 10ms/step - loss: 0.0281 - root_mean_squared_error: 0.1676 - val_loss: 0.0837 - val_root_mean_squared_error: 0.2893
# Epoch 7/10
# 3840/3840 [==============================] - 38s 10ms/step - loss: 0.0267 - root_mean_squared_error: 0.1635 - val_loss: 0.0716 - val_root_mean_squared_error: 0.2675
# Epoch 8/10
# 3840/3840 [==============================] - 38s 10ms/step - loss: 0.0268 - root_mean_squared_error: 0.1638 - val_loss: 0.0741 - val_root_mean_squared_error: 0.2723
# Epoch 9/10
# 3840/3840 [==============================] - 38s 10ms/step - loss: 0.0254 - root_mean_squared_error: 0.1594 - val_loss: 0.0879 - val_root_mean_squared_error: 0.2964
# Epoch 10/10
# 3840/3840 [==============================] - 38s 10ms/step - loss: 0.0253 - root_mean_squared_error: 0.1592 - val_loss: 0.0875 - val_root_mean_squared_error: 0.2957

# %%
plt.figure(figsize=(10,8))
plt.plot(range(len(train_scores)),train_scores,label='Train Scores')
plt.plot(range(len(val_scores)),val_scores,label='Validation Scores')
plt.plot(range(len(test_scores)),test_scores,label='Test Scores')
plt.legend()

# %% [markdown]
# ### Hold Out Score

# %% [markdown]
# Here, the same model is trained on the last n months of the Validation and tested on a Holdout Set never seen before.

# %%
n_months = 4

# %%
X_train, X_holdout, y_train, y_holdout = train_test_split(X, y, test_size=0.125, shuffle=False)

# %%
X_train = X_train[X_train['Month_Number'].isin(X_train['Month_Number'].unique()[-n_months:])]
y_train  = y_train.iloc[-X_train.shape[0]:]

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.143, shuffle=False)

# %%
X_train = preprocessing_X(X_train)
X_val = preprocessing_X(X_val)
X_holdout = preprocessing_X(X_holdout)

X_train = X_train.drop(['ID','WF','Set','Month_Number'],axis=1)
X_val = X_val.drop(['ID','WF','Set','Month_Number'],axis=1)
X_holdout = X_holdout.drop(['ID','WF','Set','Month_Number'],axis=1)

y_train,scaler = preprocessing_y(y_train)
y_val,_ = preprocessing_y(y_val)
y_holdout,_ = preprocessing_y(y_holdout)
# Out:
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))

# %%
X_train, y_train = split_sequences(X_train.values,y_train.values,n_steps)
X_val, y_val = split_sequences(X_val.values,y_val.values,n_steps)
X_holdout, y_holdout = split_sequences(X_holdout.values,y_holdout.values,n_steps)

# %%
model = LSTM_Model(input_shape)

# %%
callbacks_list = [tf.keras.callbacks.EarlyStopping(monitor=monitor, patience=patience, verbose=0, min_delta=1e-8)]
model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])
model.fit(x = X_train, y = y_train, batch_size = batch_size, epochs = epochs, validation_data = (X_val, y_val), callbacks=callbacks_list)
# Out:
# Epoch 1/10
# 2090/2090 [==============================] - 22s 11ms/step - loss: 0.1017 - root_mean_squared_error: 0.3189 - val_loss: 0.1813 - val_root_mean_squared_error: 0.4259
# Epoch 2/10
# 2090/2090 [==============================] - 21s 10ms/step - loss: 0.0645 - root_mean_squared_error: 0.2540 - val_loss: 0.1772 - val_root_mean_squared_error: 0.4210
# Epoch 3/10
# 2090/2090 [==============================] - 21s 10ms/step - loss: 0.0541 - root_mean_squared_error: 0.2326 - val_loss: 0.1351 - val_root_mean_squared_error: 0.3675
# Epoch 4/10
# 2090/2090 [==============================] - 21s 10ms/step - loss: 0.0533 - root_mean_squared_error: 0.2308 - val_loss: 0.1416 - val_root_mean_squared_error: 0.3762
# Epoch 5/10
# 2090/2090 [==============================] - 21s 10ms/step - loss: 0.0460 - root_mean_squared_error: 0.2144 - val_loss: 0.0549 - val_root_mean_squared_error: 0.2344
# Epoch 6/10
# 2090/2090 [==============================] - 21s 10ms/step - loss: 0.0455 - root_mean_squared_error: 0.2134 - val_loss: 0.0704 - val_root_mean_squared_error: 0.2654
# Epoch 7/10
# 2090/2090 [==============================] - 21s 10ms/step - loss: 0.0455 - root_mean_squared_error: 0.2132 - val_loss: 0.0668 - val_root_mean_squared_error: 0.2585
# Epoch 8/10
# 2090/2090 [==============================] - 20s 10ms/step - loss: 0.0408 - root_mean_squared_error: 0.2020 - val_loss: 0.0946 - val_root_mean_squared_error: 0.3076
# Epoch 9/10
# 2090/2090 [==============================] - 21s 10ms/step - loss: 0.0391 - root_mean_squared_error: 0.1977 - val_loss: 0.0863 - val_root_mean_squared_error: 0.2938
# Epoch 10/10
# 2090/2090 [==============================] - 21s 10ms/step - loss: 0.0389 - root_mean_squared_error: 0.1972 - val_loss: 0.1057 - val_root_mean_squared_error: 0.3251

# %%
preds = model.predict(X_holdout,batch_size = batch_size,callbacks=callbacks_list)

# %% [markdown]
# Here, Predicitions and True Labels of the Holdout Set are scaled back to measure the CAPE Error, and be compared on a Chart.

# %%
preds = scaler.inverse_transform(preds)
y_holdout = scaler.inverse_transform(pd.DataFrame(y_holdout))

# %%
def metric_cnr(preds,labels):
    cape_cnr = 100*np.sum(np.abs(preds-labels))/np.sum(labels)
    return 'CAPE', cape_cnr

# %%
metric_cnr(preds,y_holdout)
# Out:
# ('CAPE', 31.253846505955206)

# %%
plt.figure(figsize=(15,8))
preds_len = np.arange(len(y_holdout))
plt.plot(preds_len,y_holdout,label='True Values')
plt.plot(preds_len,preds,'r--',label='Predicts')
plt.legend()

# %% [markdown]
# ## Submission Generation

# %% [markdown]
# Here some different models for Submit Generation are tried. The first One works with a Expanded Window Training Set.

# %%
def WF_submit_gen(full_data,full_label,WF,input_shape,batch_size):
  # Get Data of Wind Farm
  X_WF = full_data[full_data['WF']==WF]

  full_X_train = X_WF[X_WF['Set']=='Train']
  full_X_test = X_WF[X_WF['Set']=='Test']
  full_y_train = full_label[full_label['ID'].isin(full_X_train['ID'])]

  # Months Loop
  WF_preds = pd.DataFrame(columns=['Production'])
  predicted_X_test = pd.DataFrame(columns=full_X_train.columns)
  predicted_X_test.index.names = ['Time']
  for month in full_X_test['Month_Number'].unique():

    print("Farm {} - Month {}".format(WF,month))

    # Special Condition for Month 10
    if month == 9:
      X_test = full_X_test[full_X_test['Month_Number']==month]
      X_test_10 = full_X_test[full_X_test['Month_Number']==10]
      X_test_pure = pd.concat([X_test,X_test_10])
    else:
      X_test_pure = full_X_test[full_X_test['Month_Number']==month]

    if month == 10:
      continue

    # Append Data Already Predicted
    X_train = pd.concat([full_X_train,predicted_X_test])
    y_train = pd.concat([full_y_train,WF_preds])

    # Split Train Data on Train and Validation Set
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, shuffle=False)

    # Preprocessing Data
    X_train = preprocessing_X(X_train)
    X_val = preprocessing_X(X_val)
    X_test = preprocessing_X(X_test_pure)

    # Shift-Save on X_test
    X_test = shift_save(X_test,n_steps)

    X_train = X_train.drop(['ID','WF','Set','Month_Number'],axis=1)
    X_val = X_val.drop(['ID','WF','Set','Month_Number'],axis=1)
    X_test = X_test.drop(['ID','WF','Set','Month_Number'],axis=1)

    y_train,scaler_y = preprocessing_y(y_train)
    y_val,_ = preprocessing_y(y_val)

    # Subset Creation 

    X_train, y_train = split_sequences(X_train.values,y_train.values,n_steps)
    X_val, y_val = split_sequences(X_val.values,y_val.values,n_steps)
    X_test, _ = split_sequences(X_test.values,None,n_steps)

    # Model Creation and Training
    model = LSTM_Model(input_shape,batch_size=batch_size)
    callbacks_list = [tf.keras.callbacks.EarlyStopping(monitor=monitor, patience=patience, verbose=0, min_delta=1e-8)]
    model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])
    model.fit(x = X_train, y = y_train, batch_size = batch_size, epochs = epochs, validation_data = (X_val, y_val), callbacks=callbacks_list,shuffle=False)

    # Prediction Generation
    pred = model.predict(X_test,batch_size = batch_size,callbacks=callbacks_list)
    pred = pred.reshape(pred.shape[0])
    pred = pd.DataFrame(pred,columns=['Production'])

    # Save Predictions on Final Array
    predicted_X_test = pd.concat([predicted_X_test,X_test_pure])

    pred = scaler_y.inverse_transform(pred)
    pred = pd.DataFrame(pred,columns=['Production'])
    WF_preds = pd.concat([WF_preds,pred])

  #WF_preds = scaler_y.inverse_transform(pd.DataFrame(WF_preds))
  #WF_preds = pd.DataFrame(WF_preds,columns=['Production'])

  return WF_preds

# %% [markdown]
# Here a Direct Submission Model is created. In other words, All the training data is used to forecast all the Test Data at once.

# %%
def WF_submit_gen_3(full_data,full_label,WF,input_shape,batch_size):
  # Get Data of Wind Farm
  X_WF = full_data[full_data['WF']==WF]

  # Scale X Data
  X_WF = preprocessing_X(X_WF)

  full_X_train = X_WF[X_WF['Set']=='Train']
  full_X_test = X_WF[X_WF['Set']=='Test']
  full_y_train = full_label[full_label['ID'].isin(full_X_train['ID'])]

  # Scale y_train
  full_y_train,scaler_y = preprocessing_y(full_y_train)

  # Subsets Generation
  full_X_train = full_X_train.drop(['ID','WF','Set'],axis=1)
  full_X_train, full_y_train = split_sequences(full_X_train.values,full_y_train.values,n_steps)

  full_X_test_split = full_X_test.drop(['ID','WF','Set'],axis=1)
  full_X_test_split = shift_save(full_X_test_split,n_steps)
  full_X_test_split, _ = split_sequences(full_X_test_split.values,None,n_steps)

  # Split Train Data on Train and Validation Set
  X_train, X_val, y_train, y_val = train_test_split(full_X_train, full_y_train, test_size=0.3, shuffle=False)

  # Model Creation and Training
  model = LSTM_Model(input_shape,batch_size=batch_size)
  callbacks_list = [tf.keras.callbacks.EarlyStopping(monitor=monitor, patience=patience, verbose=0, min_delta=1e-8)]
  model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])
  model.fit(x = X_train, y = y_train, batch_size = batch_size, epochs = epochs, validation_data = (X_val, y_val), callbacks=callbacks_list,shuffle=False)

  # Prediction Generation
  pred = model.predict(full_X_test_split,batch_size = batch_size,callbacks=callbacks_list)
  pred = pred.reshape(pred.shape[0])

  WF_preds = scaler_y.inverse_transform(pd.DataFrame(pred))
  WF_preds = pd.DataFrame(WF_preds,columns=['Production'])

  return WF_preds

# %% [markdown]
# Here, a model is created with Rolling Window on Training Data, instead of Expanded Window. This model is less expensive in processing.

# %%
def WF_submit_gen_4(full_data,full_label,WF,input_shape,batch_size,n_months):
  # Get Data of Wind Farm
  X_WF = full_data[full_data['WF']==WF]

  full_X_train = X_WF[X_WF['Set']=='Train']
  full_X_test = X_WF[X_WF['Set']=='Test']
  full_y_train = full_label[full_label['ID'].isin(full_X_train['ID'])]

  # Months Loop
  WF_preds = pd.DataFrame(columns=['Production'])
  predicted_X_test = pd.DataFrame(columns=full_X_train.columns)
  predicted_X_test.index.names = ['Time']
  for month in full_X_test['Month_Number'].unique():

    print("Farm {} - Month {}".format(WF,month))

    # Special Condition for Month 10
    if month == 9:
      X_test = full_X_test[full_X_test['Month_Number']==month]
      X_test_10 = full_X_test[full_X_test['Month_Number']==10]
      X_test_pure = pd.concat([X_test,X_test_10])
    else:
      X_test_pure = full_X_test[full_X_test['Month_Number']==month]

    if month == 10:
      continue

    # Append Data Already Predicted
    X_train = pd.concat([full_X_train,predicted_X_test])
    y_train = pd.concat([full_y_train,WF_preds])
    
    X_train = X_train[X_train['Month_Number'].isin(X_train['Month_Number'].unique()[-n_months:])]
    y_train  = y_train.iloc[-X_train.shape[0]:]

    # Split Train Data on Train and Validation Set
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, shuffle=False)

    # Preprocessing Data
    X_train = preprocessing_X(X_train)
    X_val = preprocessing_X(X_val)
    X_test = preprocessing_X(X_test_pure)

    # Shift-Save on X_test
    X_test = shift_save(X_test,n_steps)

    X_train = X_train.drop(['ID','WF','Set','Month_Number'],axis=1)
    X_val = X_val.drop(['ID','WF','Set','Month_Number'],axis=1)
    X_test = X_test.drop(['ID','WF','Set','Month_Number'],axis=1)

    y_train,scaler_y = preprocessing_y(y_train)
    y_val,_ = preprocessing_y(y_val)

    # Subset Creation 

    X_train, y_train = split_sequences(X_train.values,y_train.values,n_steps)
    X_val, y_val = split_sequences(X_val.values,y_val.values,n_steps)
    X_test, _ = split_sequences(X_test.values,None,n_steps)

    # Model Creation and Training
    model = LSTM_Model(input_shape,batch_size=batch_size)
    callbacks_list = [tf.keras.callbacks.EarlyStopping(monitor=monitor, patience=patience, verbose=0, min_delta=1e-8)]
    model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])
    model.fit(x = X_train, y = y_train, batch_size = batch_size, epochs = epochs, validation_data = (X_val, y_val), callbacks=callbacks_list,shuffle=False)

    # Prediction Generation
    pred = model.predict(X_test,batch_size = batch_size,callbacks=callbacks_list)
    pred = pred.reshape(pred.shape[0])
    pred = pd.DataFrame(pred,columns=['Production'])

    # Save Predictions on Final Array
    predicted_X_test = pd.concat([predicted_X_test,X_test_pure])

    pred = scaler_y.inverse_transform(pred)
    pred = pd.DataFrame(pred,columns=['Production'])
    WF_preds = pd.concat([WF_preds,pred])

  return WF_preds

# %%
def WF_submit_gen_5(full_data,full_label,WF,input_shape,batch_size):
  # Get Data of Wind Farm
  X_WF = full_data[full_data['WF']==WF]

  full_X_train = X_WF[X_WF['Set']=='Train']
  full_X_test = X_WF[X_WF['Set']=='Test']
  full_y_train = full_label[full_label['ID'].isin(full_X_train['ID'])]

  X_train, X_val, y_train, y_val = train_test_split(full_X_train, full_y_train, test_size=0.2, shuffle=False)
    
  # Preprocessing Data
  X_train = preprocessing_X(X_train)
  X_val = preprocessing_X(X_val)

  X_train = X_train.drop(['ID','WF','Set','Month_Number'],axis=1)
  X_val = X_val.drop(['ID','WF','Set','Month_Number'],axis=1)

  y_train,scaler_y = preprocessing_y(y_train)
  y_val,_ = preprocessing_y(y_val)

  # Subset Creation 

  X_train, y_train = split_sequences(X_train.values,y_train.values,n_steps)
  X_val, y_val = split_sequences(X_val.values,y_val.values,n_steps)

  model = LSTM_Model(input_shape,batch_size=batch_size)
  callbacks_list = [tf.keras.callbacks.EarlyStopping(monitor=monitor, patience=patience, verbose=0, min_delta=1e-8)]
  model.compile(optimizer='adam', loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])
  model.fit(x = X_train, y = y_train, batch_size = batch_size, epochs = epochs, validation_data = (X_val, y_val), callbacks=callbacks_list,shuffle=False)


  # Months Loop
  WF_preds = pd.DataFrame(columns=['Production'])
  for month in full_X_test['Month_Number'].unique():

    print("Farm {} - Month {}".format(WF,month))

    # Special Condition for Month 10
    if month == 9:
      X_test = full_X_test[full_X_test['Month_Number']==month]
      X_test_10 = full_X_test[full_X_test['Month_Number']==10]
      X_test_pure = pd.concat([X_test,X_test_10])
    else:
      X_test_pure = full_X_test[full_X_test['Month_Number']==month]

    if month == 10:
      continue

    # Preprocessing Data
    X_test = preprocessing_X(X_test_pure)

    # Shift-Save on X_test
    X_test = shift_save(X_test,n_steps)

    X_test = X_test.drop(['ID','WF','Set','Month_Number'],axis=1)

    # Subset Creation 
    X_test, _ = split_sequences(X_test.values,None,n_steps)

    # Prediction Generation
    pred = model.predict(X_test,batch_size = batch_size,callbacks=callbacks_list)
    pred = pred.reshape(pred.shape[0])
    pred = pd.DataFrame(pred,columns=['Production'])
    
    # Retrain with Predicted Data
    model.fit(x = X_test, y = pred, batch_size = batch_size, epochs = epochs,shuffle=False)

    pred = scaler_y.inverse_transform(pred)
    pred = pd.DataFrame(pred,columns=['Production'])
    WF_preds = pd.concat([WF_preds,pred])

  #WF_preds = scaler_y.inverse_transform(pd.DataFrame(WF_preds))
  #WF_preds = pd.DataFrame(WF_preds,columns=['Production'])

  return WF_preds

# %% [markdown]
# Here, the Submission Generation Model is applied to each Wind Farm.

# %%
final_preds = pd.DataFrame()
for WF in full_data['WF'].unique():
  WF_preds = WF_submit_gen_5(full_data,full_label,WF,input_shape,batch_size)
  final_preds = final_preds.append(WF_preds)
# Out:
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 4932/4932 [==============================] - 52s 11ms/step - loss: 0.2561 - root_mean_squared_error: 0.5060 - val_loss: 0.5046 - val_root_mean_squared_error: 0.7104
# Epoch 2/10
# 4932/4932 [==============================] - 51s 10ms/step - loss: 0.2571 - root_mean_squared_error: 0.5071 - val_loss: 0.5177 - val_root_mean_squared_error: 0.7195
# Epoch 3/10
# 4932/4932 [==============================] - 50s 10ms/step - loss: 0.2443 - root_mean_squared_error: 0.4942 - val_loss: 0.4170 - val_root_mean_squared_error: 0.6457
# Epoch 4/10
# 4932/4932 [==============================] - 51s 10ms/step - loss: 0.1316 - root_mean_squared_error: 0.3627 - val_loss: 0.2480 - val_root_mean_squared_error: 0.4980
# Epoch 5/10
# 4932/4932 [==============================] - 51s 10ms/step - loss: 0.1049 - root_mean_squared_error: 0.3238 - val_loss: 0.1789 - val_root_mean_squared_error: 0.4230
# Epoch 6/10
# 4932/4932 [==============================] - 50s 10ms/step - loss: 0.1026 - root_mean_squared_error: 0.3203 - val_loss: 0.1782 - val_root_mean_squared_error: 0.4221
# Epoch 7/10
# 4932/4932 [==============================] - 51s 10ms/step - loss: 0.1040 - root_mean_squared_error: 0.3225 - val_loss: 0.2049 - val_root_mean_squared_error: 0.4526
# Epoch 8/10
# 4932/4932 [==============================] - 51s 10ms/step - loss: 0.0963 - root_mean_squared_error: 0.3103 - val_loss: 0.2106 - val_root_mean_squared_error: 0.4589
# Epoch 9/10
# 4932/4932 [==============================] - 51s 10ms/step - loss: 0.0911 - root_mean_squared_error: 0.3018 - val_loss: 0.1674 - val_root_mean_squared_error: 0.4092
# Epoch 10/10
# 4932/4932 [==============================] - 51s 10ms/step - loss: 0.0904 - root_mean_squared_error: 0.3007 - val_loss: 0.1782 - val_root_mean_squared_error: 0.4222
# Farm WF1 - Month 1
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 383/383 [==============================] - 4s 10ms/step - loss: 0.0161 - root_mean_squared_error: 0.1270
# Epoch 2/10
# 383/383 [==============================] - 4s 10ms/step - loss: 0.0128 - root_mean_squared_error: 0.1132
# Epoch 3/10
# 383/383 [==============================] - 4s 10ms/step - loss: 0.0138 - root_mean_squared_error: 0.1177
# Epoch 4/10
# 383/383 [==============================] - 4s 10ms/step - loss: 0.0127 - root_mean_squared_error: 0.1129
# Epoch 5/10
# 383/383 [==============================] - 4s 10ms/step - loss: 0.0123 - root_mean_squared_error: 0.1108
# Epoch 6/10
# 383/383 [==============================] - 4s 10ms/step - loss: 0.0129 - root_mean_squared_error: 0.1136
# Epoch 7/10
# 383/383 [==============================] - 4s 10ms/step - loss: 0.0109 - root_mean_squared_error: 0.1042
# Epoch 8/10
# 383/383 [==============================] - 4s 9ms/step - loss: 0.0135 - root_mean_squared_error: 0.1164
# Epoch 9/10
# 383/383 [==============================] - 4s 10ms/step - loss: 0.0132 - root_mean_squared_error: 0.1151
# Epoch 10/10
# 383/383 [==============================] - 4s 10ms/step - loss: 0.0123 - root_mean_squared_error: 0.1111
# Farm WF1 - Month 2
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 672/672 [==============================] - 6s 10ms/step - loss: 0.0063 - root_mean_squared_error: 0.0791
# Epoch 2/10
# 672/672 [==============================] - 6s 10ms/step - loss: 0.0072 - root_mean_squared_error: 0.0849
# Epoch 3/10
# 672/672 [==============================] - 7s 10ms/step - loss: 0.0064 - root_mean_squared_error: 0.0800
# Epoch 4/10
# 672/672 [==============================] - 7s 10ms/step - loss: 0.0068 - root_mean_squared_error: 0.0826
# Farm WF1 - Month 3
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0063 - root_mean_squared_error: 0.0795
# Epoch 2/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0067 - root_mean_squared_error: 0.0820
# Epoch 3/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0064 - root_mean_squared_error: 0.0798
# Epoch 4/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0065 - root_mean_squared_error: 0.0803
# Farm WF1 - Month 4
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 720/720 [==============================] - 7s 10ms/step - loss: 0.0075 - root_mean_squared_error: 0.0864
# Epoch 2/10
# 720/720 [==============================] - 7s 10ms/step - loss: 0.0069 - root_mean_squared_error: 0.0830
# Epoch 3/10
# 720/720 [==============================] - 7s 10ms/step - loss: 0.0085 - root_mean_squared_error: 0.0922
# Epoch 4/10
# 720/720 [==============================] - 8s 11ms/step - loss: 0.0075 - root_mean_squared_error: 0.0866
# Epoch 5/10
# 720/720 [==============================] - 7s 10ms/step - loss: 0.0071 - root_mean_squared_error: 0.0841: 1s - loss: 0.0073 - root_mean_sq
# Farm WF1 - Month 5
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0059 - root_mean_squared_error: 0.0771
# Epoch 2/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0061 - root_mean_squared_error: 0.0783
# Epoch 3/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0052 - root_mean_squared_error: 0.0723
# Epoch 4/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0060 - root_mean_squared_error: 0.0775
# Epoch 5/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0061 - root_mean_squared_error: 0.0781
# Epoch 6/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0054 - root_mean_squared_error: 0.0736
# Farm WF1 - Month 6
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 720/720 [==============================] - 7s 10ms/step - loss: 0.0048 - root_mean_squared_error: 0.0690
# Epoch 2/10
# 720/720 [==============================] - 7s 10ms/step - loss: 0.0045 - root_mean_squared_error: 0.0667
# Epoch 3/10
# 720/720 [==============================] - 7s 10ms/step - loss: 0.0046 - root_mean_squared_error: 0.0679
# Epoch 4/10
# 720/720 [==============================] - 7s 10ms/step - loss: 0.0050 - root_mean_squared_error: 0.0706
# Epoch 5/10
# 720/720 [==============================] - 7s 10ms/step - loss: 0.0046 - root_mean_squared_error: 0.0679
# Farm WF1 - Month 7
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0066 - root_mean_squared_error: 0.0811
# Epoch 2/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0050 - root_mean_squared_error: 0.0706
# Epoch 3/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0050 - root_mean_squared_error: 0.0706
# Epoch 4/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0041 - root_mean_squared_error: 0.0643
# Epoch 5/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0047 - root_mean_squared_error: 0.0685
# Epoch 6/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0048 - root_mean_squared_error: 0.0690
# Epoch 7/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0043 - root_mean_squared_error: 0.0658
# Farm WF1 - Month 8
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0036 - root_mean_squared_error: 0.0597
# Epoch 2/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0035 - root_mean_squared_error: 0.0590
# Epoch 3/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0038 - root_mean_squared_error: 0.0615
# Epoch 4/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0038 - root_mean_squared_error: 0.0617
# Epoch 5/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0039 - root_mean_squared_error: 0.0621
# Farm WF1 - Month 9
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 719/719 [==============================] - 7s 9ms/step - loss: 0.0039 - root_mean_squared_error: 0.0623
# Epoch 2/10
# 719/719 [==============================] - 7s 10ms/step - loss: 0.0040 - root_mean_squared_error: 0.0636
# Epoch 3/10
# 719/719 [==============================] - 7s 10ms/step - loss: 0.0038 - root_mean_squared_error: 0.0614
# Epoch 4/10
# 719/719 [==============================] - 7s 10ms/step - loss: 0.0037 - root_mean_squared_error: 0.0609
# Epoch 5/10
# 719/719 [==============================] - 7s 10ms/step - loss: 0.0040 - root_mean_squared_error: 0.0634
# Epoch 6/10
# 719/719 [==============================] - 7s 10ms/step - loss: 0.0036 - root_mean_squared_error: 0.0597
# Epoch 7/10
# 719/719 [==============================] - 7s 10ms/step - loss: 0.0040 - root_mean_squared_error: 0.0635
# Epoch 8/10
# 719/719 [==============================] - 7s 10ms/step - loss: 0.0035 - root_mean_squared_error: 0.0593
# Epoch 9/10
# 719/719 [==============================] - 7s 10ms/step - loss: 0.0040 - root_mean_squared_error: 0.0631
# Epoch 10/10
# 719/719 [==============================] - 7s 10ms/step - loss: 0.0038 - root_mean_squared_error: 0.0619
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 4932/4932 [==============================] - 53s 11ms/step - loss: 0.0861 - root_mean_squared_error: 0.2934 - val_loss: 0.2763 - val_root_mean_squared_error: 0.5256
# Epoch 2/10
# 4932/4932 [==============================] - 51s 10ms/step - loss: 0.0793 - root_mean_squared_error: 0.2817 - val_loss: 0.2712 - val_root_mean_squared_error: 0.5208
# Epoch 3/10
# 4932/4932 [==============================] - 51s 10ms/step - loss: 0.0820 - root_mean_squared_error: 0.2864 - val_loss: 0.3208 - val_root_mean_squared_error: 0.5664
# Epoch 4/10
# 4932/4932 [==============================] - 51s 10ms/step - loss: 0.0805 - root_mean_squared_error: 0.2836 - val_loss: 0.2745 - val_root_mean_squared_error: 0.5240
# Epoch 5/10
# 4932/4932 [==============================] - 52s 11ms/step - loss: 0.0816 - root_mean_squared_error: 0.2856 - val_loss: 0.2748 - val_root_mean_squared_error: 0.5242
# Farm WF2 - Month 1
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 383/383 [==============================] - 4s 10ms/step - loss: 1.6588e-04 - root_mean_squared_error: 0.0129
# Epoch 2/10
# 383/383 [==============================] - 4s 10ms/step - loss: 1.1529e-04 - root_mean_squared_error: 0.0107: 1s - loss: 1.2842e-04 - root_mean_squared_error - ETA: 0s - loss: 1.2412e-04 - root_mean_squ
# Epoch 3/10
# 383/383 [==============================] - 4s 10ms/step - loss: 9.3466e-05 - root_mean_squared_error: 0.0097
# Epoch 4/10
# 383/383 [==============================] - 4s 10ms/step - loss: 6.5012e-05 - root_mean_squared_error: 0.0081
# Epoch 5/10
# 383/383 [==============================] - 4s 9ms/step - loss: 3.4966e-05 - root_mean_squared_error: 0.0059
# Epoch 6/10
# 383/383 [==============================] - 4s 9ms/step - loss: 2.7922e-05 - root_mean_squared_error: 0.0053
# Epoch 7/10
# 383/383 [==============================] - 4s 10ms/step - loss: 1.3867e-05 - root_mean_squared_error: 0.0037
# Epoch 8/10
# 383/383 [==============================] - 4s 9ms/step - loss: 8.2669e-06 - root_mean_squared_error: 0.0029
# Epoch 9/10
# 383/383 [==============================] - 4s 9ms/step - loss: 3.5832e-06 - root_mean_squared_error: 0.0019A: 2s - loss
# Epoch 10/10
# 383/383 [==============================] - 4s 10ms/step - loss: 2.7759e-06 - root_mean_squared_error: 0.0017
# Farm WF2 - Month 2
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 672/672 [==============================] - 7s 10ms/step - loss: 1.4557e-06 - root_mean_squared_error: 0.0012
# Epoch 2/10
# 672/672 [==============================] - 6s 10ms/step - loss: 7.8354e-07 - root_mean_squared_error: 8.8518e-04: 1s - loss: 8.7893e-07 - r
# Epoch 3/10
# 672/672 [==============================] - 6s 10ms/step - loss: 4.5743e-07 - root_mean_squared_error: 6.7634e-04
# Epoch 4/10
# 672/672 [==============================] - 6s 10ms/step - loss: 2.9300e-07 - root_mean_squared_error: 5.4129e-04
# Epoch 5/10
# 672/672 [==============================] - 7s 10ms/step - loss: 1.4896e-07 - root_mean_squared_error: 3.8596e-04
# Epoch 6/10
# 672/672 [==============================] - 6s 10ms/step - loss: 1.5557e-07 - root_mean_squared_error: 3.9442e-04
# Epoch 7/10
# 672/672 [==============================] - 6s 10ms/step - loss: 8.1465e-08 - root_mean_squared_error: 2.8542e-04
# Epoch 8/10
# 672/672 [==============================] - 6s 10ms/step - loss: 7.6256e-08 - root_mean_squared_error: 2.7615e-04
# Epoch 9/10
# 672/672 [==============================] - 6s 10ms/step - loss: 6.4193e-08 - root_mean_squared_error: 2.5336e-04
# Epoch 10/10
# 672/672 [==============================] - 7s 10ms/step - loss: 4.1872e-08 - root_mean_squared_error: 2.0463e-04
# Farm WF2 - Month 3
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 744/744 [==============================] - 7s 10ms/step - loss: 2.1034e-08 - root_mean_squared_error: 1.4503e-04
# Epoch 2/10
# 744/744 [==============================] - 7s 10ms/step - loss: 5.1980e-08 - root_mean_squared_error: 2.2799e-04
# Epoch 3/10
# 744/744 [==============================] - 7s 10ms/step - loss: 3.8707e-08 - root_mean_squared_error: 1.9674e-04
# Epoch 4/10
# 744/744 [==============================] - 7s 10ms/step - loss: 1.9885e-08 - root_mean_squared_error: 1.4101e-04
# Epoch 5/10
# 744/744 [==============================] - 7s 10ms/step - loss: 5.9342e-08 - root_mean_squared_error: 2.4360e-04
# Epoch 6/10
# 744/744 [==============================] - 7s 10ms/step - loss: 2.2745e-08 - root_mean_squared_error: 1.5081e-04
# Epoch 7/10
# 744/744 [==============================] - 7s 10ms/step - loss: 1.0796e-07 - root_mean_squared_error: 3.2857e-04
# Farm WF2 - Month 4
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 720/720 [==============================] - 7s 10ms/step - loss: 3.9229e-08 - root_mean_squared_error: 1.9806e-04
# Epoch 2/10
# 720/720 [==============================] - 7s 10ms/step - loss: 7.2478e-08 - root_mean_squared_error: 2.6922e-04
# Epoch 3/10
# 720/720 [==============================] - 7s 10ms/step - loss: 1.1271e-08 - root_mean_squared_error: 1.0617e-04
# Epoch 4/10
# 720/720 [==============================] - 7s 10ms/step - loss: 1.1884e-07 - root_mean_squared_error: 3.4473e-04
# Epoch 5/10
# 720/720 [==============================] - 7s 10ms/step - loss: 3.0489e-08 - root_mean_squared_error: 1.7461e-04: 3s -
# Epoch 6/10
# 720/720 [==============================] - 7s 10ms/step - loss: 9.4598e-08 - root_mean_squared_error: 3.0757e-04
# Farm WF2 - Month 5
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 744/744 [==============================] - 7s 10ms/step - loss: 6.1057e-08 - root_mean_squared_error: 2.4710e-04
# Epoch 2/10
# 744/744 [==============================] - 7s 10ms/step - loss: 1.3361e-08 - root_mean_squared_error: 1.1559e-04
# Epoch 3/10
# 744/744 [==============================] - 7s 10ms/step - loss: 3.6761e-08 - root_mean_squared_error: 1.9173e-04
# Epoch 4/10
# 744/744 [==============================] - 7s 10ms/step - loss: 4.5140e-08 - root_mean_squared_error: 2.1246e-04
# Epoch 5/10
# 744/744 [==============================] - 7s 10ms/step - loss: 7.3958e-08 - root_mean_squared_error: 2.7195e-04
# Farm WF2 - Month 6
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 720/720 [==============================] - 7s 10ms/step - loss: 1.1415e-08 - root_mean_squared_error: 1.0684e-04
# Epoch 2/10
# 720/720 [==============================] - 7s 10ms/step - loss: 1.8469e-08 - root_mean_squared_error: 1.3590e-04
# Epoch 3/10
# 720/720 [==============================] - 7s 9ms/step - loss: 1.7186e-08 - root_mean_squared_error: 1.3110e-04A: 1s - loss: 1.8002e-08 - r
# Epoch 4/10
# 720/720 [==============================] - 7s 9ms/step - loss: 1.2386e-08 - root_mean_squared_error: 1.1129e-04
# Farm WF2 - Month 7
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 744/744 [==============================] - 7s 10ms/step - loss: 4.9032e-08 - root_mean_squared_error: 2.2143e-04
# Epoch 2/10
# 744/744 [==============================] - 7s 10ms/step - loss: 1.3409e-08 - root_mean_squared_error: 1.1580e-04
# Epoch 3/10
# 744/744 [==============================] - 7s 10ms/step - loss: 1.8545e-08 - root_mean_squared_error: 1.3618e-04
# Epoch 4/10
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0083 - root_mean_squared_error: 0.0909
# Epoch 2/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0083 - root_mean_squared_error: 0.0913
# Epoch 3/10
# 744/744 [==============================] - 7s 9ms/step - loss: 0.0075 - root_mean_squared_error: 0.0865
# Epoch 4/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0083 - root_mean_squared_error: 0.0913
# Epoch 5/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0083 - root_mean_squared_error: 0.0911
# Epoch 6/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0094 - root_mean_squared_error: 0.0969
# Farm WF6 - Month 4
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 720/720 [==============================] - 7s 10ms/step - loss: 0.0050 - root_mean_squared_error: 0.0708
# Epoch 2/10
# 720/720 [==============================] - 7s 10ms/step - loss: 0.0048 - root_mean_squared_error: 0.0692
# Epoch 3/10
# 720/720 [==============================] - 7s 10ms/step - loss: 0.0057 - root_mean_squared_error: 0.0757
# Epoch 4/10
# 720/720 [==============================] - 7s 10ms/step - loss: 0.0063 - root_mean_squared_error: 0.0793
# Epoch 5/10
# 720/720 [==============================] - 7s 10ms/step - loss: 0.0052 - root_mean_squared_error: 0.0723
# Farm WF6 - Month 5
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0072 - root_mean_squared_error: 0.0847
# Epoch 2/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0066 - root_mean_squared_error: 0.0812
# Epoch 3/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0065 - root_mean_squared_error: 0.0806
# Epoch 4/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0069 - root_mean_squared_error: 0.0828
# Epoch 5/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0078 - root_mean_squared_error: 0.0884
# Epoch 6/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0072 - root_mean_squared_error: 0.0849
# Farm WF6 - Month 6
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 720/720 [==============================] - 7s 10ms/step - loss: 0.0042 - root_mean_squared_error: 0.0649
# Epoch 2/10
# 720/720 [==============================] - 7s 10ms/step - loss: 0.0066 - root_mean_squared_error: 0.0810
# Epoch 3/10
# 720/720 [==============================] - 7s 10ms/step - loss: 0.0068 - root_mean_squared_error: 0.0827
# Epoch 4/10
# 720/720 [==============================] - 7s 10ms/step - loss: 0.0044 - root_mean_squared_error: 0.0661
# Farm WF6 - Month 7
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0048 - root_mean_squared_error: 0.0692
# Epoch 2/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0040 - root_mean_squared_error: 0.0633
# Epoch 3/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0048 - root_mean_squared_error: 0.0693
# Epoch 4/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0039 - root_mean_squared_error: 0.0621
# Epoch 5/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0047 - root_mean_squared_error: 0.0684
# Epoch 6/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0046 - root_mean_squared_error: 0.0675
# Epoch 7/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0040 - root_mean_squared_error: 0.0629
# Farm WF6 - Month 8
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0036 - root_mean_squared_error: 0.0599
# Epoch 2/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0042 - root_mean_squared_error: 0.0652
# Epoch 3/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0034 - root_mean_squared_error: 0.0585
# Epoch 4/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0032 - root_mean_squared_error: 0.0563
# Epoch 5/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0035 - root_mean_squared_error: 0.0595
# Epoch 6/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0029 - root_mean_squared_error: 0.0536
# Epoch 7/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0029 - root_mean_squared_error: 0.0535
# Epoch 8/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0029 - root_mean_squared_error: 0.0541
# Epoch 9/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0033 - root_mean_squared_error: 0.0573
# Epoch 10/10
# 744/744 [==============================] - 7s 10ms/step - loss: 0.0033 - root_mean_squared_error: 0.0578
# Farm WF6 - Month 9
# <ipython-input-7-77d29a6893c2>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 100m"] = np.sin(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 100m"] = np.cos(X['Wind Direction 100m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Sin_Wind Direction 10m"] = np.sin(X['Wind Direction 10m']*(np.pi/180))
# <ipython-input-7-77d29a6893c2>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directions["Cos_Wind Direction 10m"] = np.cos(X['Wind Direction 10m']*(np.pi/180))
# Epoch 1/10
# 719/719 [==============================] - 7s 10ms/step - loss: 0.0036 - root_mean_squared_error: 0.0603
# Epoch 2/10
# 719/719 [==============================] - 7s 10ms/step - loss: 0.0042 - root_mean_squared_error: 0.0650
# Epoch 3/10
# 719/719 [==============================] - 7s 10ms/step - loss: 0.0040 - root_mean_squared_error: 0.0629
# Epoch 4/10
# 719/719 [==============================] - 7s 10ms/step - loss: 0.0034 - root_mean_squared_error: 0.0585: 0s - loss: 0.0034 - root_mean_squared_error: 0.05
# Epoch 5/10
# 719/719 [==============================] - 7s 10ms/step - loss: 0.0030 - root_mean_squared_error: 0.0544
# Epoch 6/10
# 719/719 [==============================] - 7s 10ms/step - loss: 0.0042 - root_mean_squared_error: 0.0651: 2s - los
# Epoch 7/10
# 719/719 [==============================] - 7s 10ms/step - loss: 0.0037 - root_mean_squared_error: 0.0612
# Epoch 8/10
# 719/719 [==============================] - 7s 10ms/step - loss: 0.0040 - root_mean_squared_error: 0.0632

# %% [markdown]
# Finally the Submit File is created, and a Final Plot of the Submission is done.

# %%
final_preds = final_preds.reset_index().drop('index',axis=1)
final_preds['ID'] = pd.read_csv(r'C:\Users\andre_\OneDrive\Documentos\GitHub\cnr\Data\random_submission_example.csv')['ID']
final_preds = final_preds.set_index('ID')

# %%
final_preds
# Out:
#        Production
# ID
# 37376    1.478220
# 37377    1.399402
# 37378    0.724499
# 37379    0.837382
# 37380    0.701269
# ...           ...
# 73900    0.100248
# 73901    0.096780
# 73902    0.097169
# 73903    0.095864
# 73904    0.097158
#
# [36529 rows x 1 columns]

# %%
plt.plot(final_preds.index,final_preds['Production'])

# %%
final_preds.to_csv('Submission_LSTM.csv')
